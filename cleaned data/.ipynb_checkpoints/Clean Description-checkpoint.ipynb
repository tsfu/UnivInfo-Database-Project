# %%
import csv
import pandas as pd

# %%
ranking = pd.read_csv("rank.csv")

# %%
ranking
# Out:
#      unitid                              chronname  Rank  \
# 0    186131                   Princeton University     1
# 1    166027                     Harvard University     2
# 2    130794                        Yale University     3
# 3    144050                  University of Chicago     3
# 4    190150                    Columbia University     5
# 5    243744                    Stanford University     5
# 6    166683  Massachusetts Institute of Technology     7
# 7    198419                        Duke University     8
# 8    215062             University of Pennsylvania     8
# 9    162928               Johns Hopkins University    10
# 10   182670                      Dartmouth College    11
# 11   110404     California Institute of Technology    12
# 12   147767                Northwestern University    12
# 13   217156                       Brown University    14
# 14   152080               University of Notre Dame    15
# ...

# %%
def add(x):
    return '"'+x+'"'

# %%
ranking['Description'] = ranking['Description'].apply(add)

# %%
ranking
# Out:
#      unitid                              chronname  Rank  \
# 0    186131                   Princeton University     1
# 1    166027                     Harvard University     2
# 2    130794                        Yale University     3
# 3    144050                  University of Chicago     3
# 4    190150                    Columbia University     5
# 5    243744                    Stanford University     5
# 6    166683  Massachusetts Institute of Technology     7
# 7    198419                        Duke University     8
# 8    215062             University of Pennsylvania     8
# 9    162928               Johns Hopkins University    10
# 10   182670                      Dartmouth College    11
# 11   110404     California Institute of Technology    12
# 12   147767                Northwestern University    12
# 13   217156                       Brown University    14
# 14   152080               University of Notre Dame    15
# ...

# %%
ranking.to_csv('rank.csv',index = False)
